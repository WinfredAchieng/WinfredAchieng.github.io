# %% [markdown]
# <a href="https://colab.research.google.com/github/WinfredAchieng/WinfredAchieng.github.io/blob/main/Winfred_Achieng_week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the dataset

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bfb1ab40-e847-4dd3-8ebc-eec6b2a665ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfb1ab40-e847-4dd3-8ebc-eec6b2a665ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Importing the dataset

# %%
import pandas as pd
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # Exploring the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %% [markdown]
# # Visualizing Relationships

# %%
import matplotlib.pyplot as plt
plt.scatter(df["area"],df["price"])
plt.xlabel("area(sq ft)")
plt.ylabel("price")
plt.title("area vs price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df[["area"]]  #2D
y = df["price"]   #1D

# %% [markdown]
# # Training Model on all data

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict all the data

# %%
y_pred = model.predict(x)

# %% [markdown]
# # Evaluation Metrics

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 11246.57534246575
# MSE: 186815068.4931509
# RMSE: 13668.030893042014
# R2 Score: 0.9584301138199486

# %% [markdown]
# # Visualization of the Regression Line

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y, color="blue")          # Actual prices
plt.plot(x, y_pred, color="red")         # Predicted regression line
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.title("Linear Regression: Area vs Price")
plt.show()
